# %% [markdown]
# <a href="https://colab.research.google.com/github/Sardaar2003/GFG_Data_Science_Course_Assignment/blob/main/Heart_Dataset_For_Visualisation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
import seaborn as sns

# %%
data=pd.read_csv('heart.csv')
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
data.shape
# Out:
# (918, 12)

# %%
data.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
sns.displot(data['Age'])

# %%
sns.displot(data['Age'],kde=False)

# %%
sns.distplot(data['Age'],kde=False,hist=True)
# Out:
# <ipython-input-113-e715bc8c7a92>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'],kde=False,hist=True)
# <Axes: xlabel='Age'>

# %%
sns.distplot(data['Age'],kde=True,hist=True,rug=True)
# Out:
# <ipython-input-114-d849ccec7d8a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'],kde=True,hist=True,rug=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(data['Age'],kde=True,hist=True,rug=True,bins=100)
# Out:
# <ipython-input-115-56febfbfeef5>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'],kde=True,hist=True,rug=True,bins=100)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(data['Age'])
# Out:
# <ipython-input-116-ec135ce2bd5e>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
for i in data.columns:
  sns.displot(data[i],color='blue',kde=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
sns.displot(data['Age'],color='blue',kde=True)

# %%
sns.displot(data['RestingBP'],kde=True,color='blue')

# %% [markdown]
# ##Pie Chart for Categorical Value

# %%
data.groupby('Sex').size().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: >

# %%
data.groupby('ChestPainType').size().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: >

# %%
data.groupby('RestingECG').size().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: >

# %%
data.groupby('ST_Slope').size().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: >

# %%
data.groupby('HeartDisease').size().plot(kind='pie',autopct='%.1f%%')
# Out:
# <Axes: >

# %% [markdown]
# ## ViolinPlot

# %%
sns.violinplot(data['Age'])
# Out:
# <Axes: >

# %%
sns.violinplot(y=data['Sex'],x=data['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sns.violinplot(y=data['Age'],x=data['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.violinplot(y=data['Cholesterol'],x=data['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(y=data['ExerciseAngina'],x=data['HeartDisease'])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='ExerciseAngina'>

# %% [markdown]
# ## Correlation Heatmap

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
data.corr()
# Out:
# <ipython-input-133-c44ded798807>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# ...

# %%
sns.heatmap(data.corr())
# Out:
# <ipython-input-134-8b96879b4d02>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data.corr())
# <Axes: >

# %% [markdown]
# ## Join Plot

# %%
sns.jointplot(x=data['Age'],y=data['MaxHR'],kind='hex')

# %%
sns.jointplot(x=data['Age'],y=data['MaxHR'],kind='reg')

# %%
sns.jointplot(x=data['Age'],y=data['Age'])

# %%
sns.jointplot(x=data['HeartDisease'],y=data['Oldpeak'])

# %%
sns.jointplot(x=data['Cholesterol'],y=data['Oldpeak'])

# %%
data.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
sns.jointplot(x='Cholesterol',y='FastingBS',data=data,kind='reg')

# %%
sns.jointplot(x='HeartDisease',y='MaxHR',data=data,kind='reg')

# %% [markdown]
# ## Pair Plot

# %%
sns.pairplot(data)
