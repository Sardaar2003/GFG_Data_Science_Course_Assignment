# %% [markdown]
# <a href="https://colab.research.google.com/github/Sardaar2003/GFG_Data_Science_Course_Assignment/blob/main/Introduction_to_Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics as st

# %%
df=pd.read_csv('Students_marks.csv')
df
# Out:
#    Roll No.     Name Gender  Data Structure  Mathematics  Operating System  \
# 0         1  Avneet       F              25           19                17
# 1         2      Jay      M              23           21                14
# 2         3   Sadaf       F              28           23                21
# 3         4  Prakash      M              21           27                28
# 4         5   Sarita      F              23           22                 9
# 5         6  Vasudha      F             190           30                28
# 6         7    Ankur      M              24           24                22
# 7         8    Laksh      M              26           25                27
# 8         9     Aman      M              23           18                25
# 9        10    Rajat      M              24           22                15
#
#    Average marks    Ranking
# 0          20.33       Good
# 1          19.33       Okay
# 2          24.00       Good
# ...

# %%
df.describe()
# Out:
#        Roll No.  Data Structure  Mathematics  Operating System  Average marks
# count  10.00000       10.000000     10.00000         10.000000      10.000000
# mean    5.50000       40.700000     23.10000         20.600000      28.131000
# std     3.02765       52.493492      3.60401          6.619836      19.337093
# min     1.00000       21.000000     18.00000          9.000000      18.000000
# 25%     3.25000       23.000000     21.25000         15.500000      20.330000
# 50%     5.50000       24.000000     22.50000         21.500000      22.665000
# 75%     7.75000       25.750000     24.75000         26.500000      24.997500
# max    10.00000      190.000000     30.00000         28.000000      82.660000

# %%
df.drop(index=5,inplace=True)

# %%
df.reset_index()
# Out:
#    index  Roll No.     Name Gender  Data Structure  Mathematics  \
# 0      0         1  Avneet       F              25           19
# 1      1         2      Jay      M              23           21
# 2      2         3   Sadaf       F              28           23
# 3      3         4  Prakash      M              21           27
# 4      4         5   Sarita      F              23           22
# 5      6         7    Ankur      M              24           24
# 6      7         8    Laksh      M              26           25
# 7      8         9     Aman      M              23           18
# 8      9        10    Rajat      M              24           22
#
#    Operating System  Average marks    Ranking
# 0                17          20.33       Good
# 1                14          19.33       Okay
# 2                21          24.00       Good
# 3                28          25.33  Very Good
# 4                 9          18.00       Okay
# ...

# %%
df.describe()
# Out:
#         Roll No.  Data Structure  Mathematics  Operating System  Average marks
# count   9.000000        9.000000     9.000000          9.000000       9.000000
# mean    5.444444       24.111111    22.333333         19.777778      22.072222
# std     3.205897        2.027588     2.828427          6.457124       2.773030
# min     1.000000       21.000000    18.000000          9.000000      18.000000
# 25%     3.000000       23.000000    21.000000         15.000000      20.330000
# 50%     5.000000       24.000000    22.000000         21.000000      22.000000
# 75%     8.000000       25.000000    24.000000         25.000000      24.000000
# max    10.000000       28.000000    27.000000         28.000000      26.000000

# %%
plt.plot(df['Name'],df['Data Structure'])
plt.title('Marks of student in DSA')
plt.xlabel('Name')
plt.ylabel('Data Structure')
plt.show()

# %%
df1=sns.load_dataset('mpg')
df1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# **Ungrouped Frequency**

# %%
df1['origin'].unique()
# Out:
# array(['usa', 'japan', 'europe'], dtype=object)

# %%
df1.shape
# Out:
# (398, 9)

# %%
df1['origin'].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
df1['origin'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df1['cylinders'].unique()
# Out:
# array([8, 4, 6, 3, 5])

# %%
df1['cylinders'].value_counts()
# Out:
# 4    204
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
df1['cylinders'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df2=pd.crosstab(df1['origin'],"Number of cars")
df2
# Out:
# col_0   Number of cars
# origin
# europe              70
# japan               79
# usa                249

# %%
df2=pd.crosstab(df1['origin'],df1['cylinders'])
df2
# Out:
# cylinders  3   4  5   6    8
# origin
# europe     0  63  3   4    0
# japan      4  69  0   6    0
# usa        0  72  0  74  103

# %%
df1['model_year'].unique()
# Out:
# array([70, 71, 72, 73, 74, 75, 76, 77, 78, 79, 80, 81, 82])

# %%
df1['model_year'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# **Relative Frequency**

# %%
df2=pd.crosstab(df1['origin'],"Number of cars")
df2
# Out:
# col_0   Number of cars
# origin
# europe              70
# japan               79
# usa                249

# %%
df2['relative_freq']=df2['Number of cars']/df2['Number of cars'].sum()
df2
# Out:
# col_0   Number of cars  relative_freq
# origin
# europe              70       0.175879
# japan               79       0.198492
# usa                249       0.625628

# %%
df2['percentage_frequency']=df2['relative_freq']*100
df2
# Out:
# col_0   Number of cars  relative_freq  percentage_frequency
# origin
# europe              70       0.175879             17.587940
# japan               79       0.198492             19.849246
# usa                249       0.625628             62.562814

# %%
df1['origin'].value_counts().plot(kind='pie',autopct="%1.f%%")
# Out:
# <Axes: ylabel='origin'>

# %% [markdown]
# **Grouped Frequency**

# %%
df1.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %%
df1['displacement'].value_counts(bins=5)
# Out:
# (67.612, 145.4]    196
# (300.2, 377.6]      73
# (222.8, 300.2]      60
# (145.4, 222.8]      44
# (377.6, 455.0]      25
# Name: displacement, dtype: int64

# %%
df1['displacement'].value_counts(bins=5).plot(kind='barh')
# Out:
# <Axes: >

# %%
df1['weight'].value_counts(bins=5)
# Out:
# (1609.472, 2318.4]    121
# (2318.4, 3023.8]      113
# (3023.8, 3729.2]       77
# (3729.2, 4434.6]       63
# (4434.6, 5140.0]       24
# Name: weight, dtype: int64

# %%
df1['weight'].value_counts(bins=5).plot(kind='barh')
# Out:
# <Axes: >

# %%
df1.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# **Central Tendency**

# %%
data=[1,1,1,2,3,4,4,4,4,5,6,7,7,7,8]

# %%
st.mean(data)
# Out:
# 4.266666666666667

# %%
df1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
st.mean(df1['mpg'])
# Out:
# 23.514572864321607

# %%
df1.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df1.median()
# Out:
# <ipython-input-119-e41201014d8f>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.median()
# mpg               23.0
# cylinders          4.0
# displacement     148.5
# horsepower        93.5
# weight          2803.5
# acceleration      15.5
# model_year        76.0
# dtype: float64

# %%
st.median(data)
# Out:
# 4

# %%
st.mode(data)
# Out:
# 4

# %%
df1.mode()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  13.0        4.0          97.0       150.0    1985          14.5
# 1   NaN        NaN           NaN         NaN    2130           NaN
#
#    model_year origin        name
# 0        73.0    usa  ford pinto
# 1         NaN    NaN         NaN

# %% [markdown]
# **Measure of Dispersion - 1**

# %%
df1.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
data1=[45,42,42,41,40]
data2=[54,48,42,33,33]

# %%
print(st.mean(data1))
print(st.mean(data2))
# Out:
# 42
# 42

# %%
print(max(data1)-min(data1))
print(max(data2)-min(data2))
# Out:
# 5
# 21

# %%
print(st.variance(data1))
print(st.variance(data2))
# Out:
# 3.5
# 85.5

# %%
print(st.pstdev(data1))
print(st.pstdev(data2))
# Out:
# 1.6733200530681511
# 8.270429251254134

# %%
df1.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df1['mpg'].max()-df1['mpg'].min()
# Out:
# 37.6

# %%
df1.var()
# Out:
# <ipython-input-137-e9bfb5b9ee38>:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.var()
# mpg                 61.089611
# cylinders            2.893415
# displacement     10872.199152
# horsepower        1481.569393
# weight          717140.990526
# acceleration         7.604848
# model_year          13.672443
# dtype: float64

# %%
df1.std()
# Out:
# <ipython-input-138-1c22e8bf5753>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.std()
# mpg               7.815984
# cylinders         1.701004
# displacement    104.269838
# horsepower       38.491160
# weight          846.841774
# acceleration      2.757689
# model_year        3.697627
# dtype: float64

# %%
df1.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# **Measure of Dispersion -2**

# %%
(df1.std()/df1.mean())*100
# Out:
# <ipython-input-140-caac101090fb>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   (df1.std()/df1.mean())*100
# <ipython-input-140-caac101090fb>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   (df1.std()/df1.mean())*100
# mpg             33.238896
# cylinders       31.183772
# displacement    53.906870
# horsepower      36.844439
# weight          28.509115
# acceleration    17.713726
# model_year       4.864655
# dtype: float64

# %%
(st.pstdev(data1)/st.mean(data1))*100
# Out:
# 3.984095364447979

# %%
(st.pstdev(data2)/st.mean(data2))*100
# Out:
# 19.691498217271747

# %%
3*(df1.mean()-df1.mode())/df1.std()
# Out:
# <ipython-input-149-fc9475f74344>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   3*(df1.mean()-df1.mode())/df1.std()
# <ipython-input-149-fc9475f74344>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   3*(df1.mean()-df1.mode())/df1.std()
#    acceleration  cylinders  displacement  horsepower  model_year       mpg  \
# 0      1.161941   2.565732      2.774318   -3.548655    2.442148  4.035796
# 1           NaN        NaN           NaN         NaN         NaN       NaN
#
#   name origin    weight
# 0  NaN    NaN  3.490940
# ...

# %%
df1.skew()
# Out:
# <ipython-input-150-da7f0cf1c7b0>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.skew()
# mpg             0.457066
# cylinders       0.526922
# displacement    0.719645
# horsepower      1.087326
# weight          0.531063
# acceleration    0.278777
# model_year      0.011535
# dtype: float64

# %%
df1['horsepower_new']=df1['horsepower']**(1/5)

# %%
df1
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name  horsepower_new
# 0            70     usa  chevrolet chevelle malibu        2.647212
# ...

# %%
df1.skew()
# Out:
# <ipython-input-156-da7f0cf1c7b0>:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.skew()
# mpg               0.457066
# cylinders         0.526922
# displacement      0.719645
# horsepower        1.087326
# weight            0.531063
# acceleration      0.278777
# model_year        0.011535
# horsepower_new    0.516785
# dtype: float64

# %%
df1.kurtosis()
# Out:
# <ipython-input-157-8fde8da7f2fe>:1: FutureWarning: The default value of numeric_only in DataFrame.kurt is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.kurtosis()
# mpg              -0.510781
# cylinders        -1.376662
# displacement     -0.746597
# horsepower        0.696947
# weight           -0.785529
# acceleration      0.419497
# model_year       -1.181232
# horsepower_new   -0.315028
# dtype: float64

# %%
a=[5,8,8,16,24,24,3016,24]
st.mode(a)
# Out:
# 24
