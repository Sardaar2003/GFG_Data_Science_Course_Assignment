# %% [markdown]
# <a href="https://colab.research.google.com/github/Sardaar2003/GFG_Data_Science_Course_Assignment/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dt1=pd.read_csv('googleplaystore.csv')

# %%
dt1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
dt1.shape
# Out:
# (10841, 13)

# %%
dt1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
dt1.dropna(inplace=True)

# %%
# dt1.fillna()

# %%
dt1.shape
# Out:
# (9360, 13)

# %%
dt1.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    0
# Genres            0
# Last Updated      0
# Current Ver       0
# Android Ver       0
# dtype: int64

# %%
dt1.shape
# Out:
# (9360, 13)

# %%
avg=float(str(dt1['Rating'].mean())[:4])
print(avg)
# Out:
# 4.19

# %%
len(dt1[dt1['Rating']==5])
# Out:
# 274

# %%
s=0
for i in dt1['Reviews']:
  s+=int(i)
print(int(s/len(dt1['Reviews'])))
# Out:
# 514376

# %%
uni=dt1['Category'].unique()
print(len(uni))
print(uni)
# Out:
# 33
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']

# %%
len(dt1[dt1['Category']=='ART_AND_DESIGN'])
# Out:
# 61

# %%
dt1['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
f=len(dt1[dt1['Type']=='Free'])
p=len(dt1[dt1['Type']=='Paid'])
print(f,p)
# Out:
# 8715 645

# %%
int(f/(f+p)*100)
# Out:
# 93

# %%
dt1['Content Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
len(dt1[dt1['Content Rating']=='Everyone'])
# Out:
# 7414

# %%
dt1['Content Rating'].value_counts()
# Out:
# Everyone           7414
# Teen               1084
# Mature 17+          461
# Everyone 10+        397
# Adults only 18+       3
# Unrated               1
# Name: Content Rating, dtype: int64

# %%
dt1['Category'].value_counts()
# Out:
# FAMILY                 1746
# GAME                   1097
# TOOLS                   733
# PRODUCTIVITY            351
# MEDICAL                 350
# COMMUNICATION           328
# FINANCE                 323
# SPORTS                  319
# PHOTOGRAPHY             317
# LIFESTYLE               314
# PERSONALIZATION         312
# BUSINESS                303
# HEALTH_AND_FITNESS      297
# SOCIAL                  259
# SHOPPING                238
# NEWS_AND_MAGAZINES      233
# TRAVEL_AND_LOCAL        226
# DATING                  195
# BOOKS_AND_REFERENCE     178
# VIDEO_PLAYERS           160
# EDUCATION               155
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     124
# FOOD_AND_DRINK          109
# HOUSE_AND_HOME           76
# WEATHER                  75
# AUTO_AND_VEHICLES        73
# LIBRARIES_AND_DEMO       64
# ART_AND_DESIGN           61
# COMICS                   58
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# ...

# %%
for i in dt1.columns:
  if (dt1[i].dtype=='object'):
    print(dt1[i].value_counts())
    print('-'*18)
# Out:
# ROBLOX                                               9
# CBS Sports App - Scores, News, Stats & Watch Live    8
# 8 Ball Pool                                          7
# Duolingo: Learn Languages Free                       7
# Candy Crush Saga                                     7
#                                                     ..
# Math Games for Pre-K - Grade 4                       1
# Radio K - KUOM                                       1
# Kpop Music Quiz (K-pop Game)                         1
# OST)                                                 1
# iHoroscope - 2018 Daily Horoscope & Astrology        1
# Name: App, Length: 8190, dtype: int64
# ------------------
# FAMILY                 1746
# GAME                   1097
# TOOLS                   733
# PRODUCTIVITY            351
# MEDICAL                 350
# COMMUNICATION           328
# FINANCE                 323
# SPORTS                  319
# PHOTOGRAPHY             317
# LIFESTYLE               314
# ...

# %% [markdown]
# **NULL Values Handling**

# %%
dt2=pd.read_csv('Data_1.csv')

# %%
dt2
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
dt2.dropna()
dt2.reset_index()
# Out:
#    index  Country   Age   Salary Purchased
# 0      0   France  44.0  72000.0       Yes
# 1      1    Spain  27.0  48000.0       Yes
# 2      2      NaN  30.0  54000.0       NaN
# 3      3    Spain  38.0  61000.0        No
# 4      4  Germany  40.0      NaN       Yes
# 5      5   France  35.0  58000.0       Yes
# 6      6    Spain   NaN  52000.0        No
# 7      7   France  48.0  79000.0       Yes
# 8      8  Germany  50.0  83000.0        No
# 9      9   France  37.0  67000.0       Yes

# %%
avg=dt2['Salary'].mean()
med=dt2['Age'].median()

# %%
# !pip install sklearn

# %%
from sklearn.impute import SimpleImputer

# %%
imputer=SimpleImputer(missing_values=np.nan,strategy='most_frequent')

# %%
dt2.iloc[:,1:3]=imputer.transform(dt2.iloc[:,1:3].values)

# %%
dt2
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2      NaN  30.0  54000.0       NaN
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
dt2.iloc[:,-1:]
# Out:
#   Purchased
# 0       Yes
# 1       Yes
# 2       NaN
# 3        No
# 4       Yes
# 5       Yes
# 6        No
# 7       Yes
# 8        No
# 9       Yes

# %%
imputer1=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
imputer1.fit(dt2.iloc[:,:1])
dt2.iloc[:,:1]=imputer1.transform(dt2.iloc[:,:1])
print(dt2)
print('-'*60)
imputer1.fit(dt2.iloc[:,-1:])
dt2.iloc[:,-1:]=imputer1.transform(dt2.iloc[:,-1:])
print(dt2)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes
# ------------------------------------------------------------
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0       Yes
# 1    Spain  27.0  48000.0       Yes
# 2   France  30.0  54000.0       Yes
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0  48000.0       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain  27.0  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
imputer1=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
imputer1.fit(dt2)
dt2=imputer1.transform(dt2)
print(dt2)
# Out:
# [['France' 44.0 72000.0 'Yes']
#  ['Spain' 27.0 48000.0 'Yes']
#  ['France' 30.0 54000.0 'Yes']
#  ['Spain' 38.0 61000.0 'No']
#  ['Germany' 40.0 48000.0 'Yes']
#  ['France' 35.0 58000.0 'Yes']
#  ['Spain' 27.0 52000.0 'No']
#  ['France' 48.0 79000.0 'Yes']
#  ['Germany' 50.0 83000.0 'No']
#  ['France' 37.0 67000.0 'Yes']]

# %%
dt1=pd.read_csv('googleplaystore.csv')
dt3=pd.read_csv('googleplaystore.csv')
dt1
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
dt1.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
imputer2=SimpleImputer(missing_values=np.nan,strategy='most_frequent')
imputer2.fit(dt1)
dt1=imputer2.transform(dt1)
print(dt1)
# Out:
# [['Photo Editor & Candy Camera & Grid & ScrapBook' 'ART_AND_DESIGN' 4.1
#   ... 'January 7, 2018' '1.0.0' '4.0.3 and up']
#  ['Coloring book moana' 'ART_AND_DESIGN' 3.9 ... 'January 15, 2018'
#   '2.0.0' '4.0.3 and up']
#  ['U Launcher Lite – FREE Live Cool Themes, Hide Apps' 'ART_AND_DESIGN'
#   4.7 ... 'August 1, 2018' '1.2.4' '4.0.3 and up']
#  ...
#  ['Parkinson Exercices FR' 'MEDICAL' 4.4 ... 'January 20, 2017' '1.0'
#   '2.2 and up']
#  ['The SCP Foundation DB fr nn5n' 'BOOKS_AND_REFERENCE' 4.5 ...
#   'January 19, 2015' 'Varies with device' 'Varies with device']
#  ['iHoroscope - 2018 Daily Horoscope & Astrology' 'LIFESTYLE' 4.5 ...
#   'July 25, 2018' 'Varies with device' 'Varies with device']]

# %%
dt1
# Out:
# array([['Photo Editor & Candy Camera & Grid & ScrapBook',
#         'ART_AND_DESIGN', 4.1, ..., 'January 7, 2018', '1.0.0',
#         '4.0.3 and up'],
#        ['Coloring book moana', 'ART_AND_DESIGN', 3.9, ...,
#         'January 15, 2018', '2.0.0', '4.0.3 and up'],
#        ['U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#         'ART_AND_DESIGN', 4.7, ..., 'August 1, 2018', '1.2.4',
#         '4.0.3 and up'],
#        ...,
#        ['Parkinson Exercices FR', 'MEDICAL', 4.4, ...,
#         'January 20, 2017', '1.0', '2.2 and up'],
#        ['The SCP Foundation DB fr nn5n', 'BOOKS_AND_REFERENCE', 4.5, ...,
#         'January 19, 2015', 'Varies with device', 'Varies with device'],
#        ['iHoroscope - 2018 Daily Horoscope & Astrology', 'LIFESTYLE',
#         4.5, ..., 'July 25, 2018', 'Varies with device',
#         'Varies with device']], dtype=object)

# %%
imputer2.fit(dt3.iloc[:,2:3])
dt3.iloc[:,2:3]=imputer2.transform(dt3.iloc[:,2:3])
print(dt3.iloc[:,2:3])
# Out:
#        Rating
# 0         4.1
# 1         3.9
# 2         4.7
# 3         4.5
# 4         4.3
# ...       ...
# 10836     4.5
# 10837     5.0
# 10838     4.4
# 10839     4.5
# 10840     4.5
#
# [10841 rows x 1 columns]

# %%
imputer2.fit(dt3.iloc[:,6:7])
dt3.iloc[:,6:7]=imputer2.transform(dt3.iloc[:,6:7])
print(dt3.iloc[:,6:7])
# Out:
#        Type
# 0      Free
# 1      Free
# 2      Free
# 3      Free
# 4      Free
# ...     ...
# 10836  Free
# 10837  Free
# 10838  Free
# 10839  Free
# 10840  Free
#
# [10841 rows x 1 columns]

# %%
dt3.isnull().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size              0
# Installs          0
# Type              0
# Price             0
# Content Rating    1
# Genres            0
# Last Updated      0
# Current Ver       8
# Android Ver       3
# dtype: int64
